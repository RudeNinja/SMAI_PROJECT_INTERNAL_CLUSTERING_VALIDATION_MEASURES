# %%
import numpy as np
from sklearn.datasets import make_classification
from sklearn.datasets import make_blobs
from sklearn.datasets import make_gaussian_quantiles

import matplotlib.pyplot as plt
import csv

# %%
plt.title("Multi-class, two informative features, one cluster", fontsize="small")
X1, Y1 = make_classification( n_samples=250,
    n_features=2, n_redundant=0, n_informative=2, n_clusters_per_class=1, n_classes=3
)
plt.scatter(X1[:, 0], X1[:, 1], marker="o", c=Y1, s=25, edgecolor="k")

# %%
plt.title("Well Separated data", fontsize="small")
X1, Y1 = make_blobs(n_samples=250,n_features=2, centers=5,cluster_std=0.5,random_state=20)
plt.scatter(X1[:, 0], X1[:, 1], marker="o", c=Y1, s=25, edgecolor="k")

# %%
print(X1.shape)

filename = "Wellseparated.csv"
with open(filename, 'w') as csvfile: 
    # creating a csv writer object 
    csvwriter = csv.writer(csvfile) 
        
    # writing the fields 
    
        
    # writing the data rows 
    csvwriter.writerows(X1)
# Out:
# (250, 2)

# %%
arr = np.loadtxt(filename,delimiter=',')

print(arr)

plt.plot(arr[:,0],arr[:,1],'.')
plt.title("Well separated Data")
# Out:
# [[ -3.13497589   0.87045551]
#  [ -2.41869684   0.36989677]
#  [  4.11157324  -5.64666041]
#  [ -1.95516641   0.81013018]
#  [ -2.54340268   0.24253243]
#  [  1.34826964   8.01129836]
#  [ -9.41499516   3.31485508]
#  [  1.29316078   7.00354253]
#  [  7.47472181   7.03829105]
#  [  7.11113932   6.16111509]
#  [ -9.55192367   4.13071801]
#  [  7.07862568   6.97373346]
#  [ -9.86374134   4.21503932]
#  [  2.74896902  -6.38509611]
#  [ -2.75375305   0.45563481]
#  [ -2.51878179   1.46638948]
#  [ -2.7552047    0.25673711]
#  [  7.27324428   5.85514587]
#  [ -2.32985243  -0.05219796]
#  [ -8.75452609   4.3927981 ]
#  [  7.81002452   6.1815861 ]
#  [  7.97539416   6.08164487]
#  [  3.23180455  -5.45376572]
#  [ -2.62981012  -0.24538773]
#  [  3.10469432  -5.16268032]
#  [ -2.37800062   0.91396086]
#  [  8.25142585   6.44252599]
#  [  1.29514704   7.14777945]
#  [  2.83437883  -5.52346326]
#  [  3.47497259  -6.83599142]
#  [  2.36487166   8.63017265]
#  [  1.70810734   8.73236778]
# ...

# %%
plt.title("subcluster data", fontsize="small")
X2, Y2 = make_blobs(n_samples=250,n_features=2, centers=5,cluster_std=0.6,random_state=61)
plt.scatter(X2[:, 0], X2[:, 1], marker="o", c=Y2, s=25, edgecolor="k")

# %%
filename2 = "Subcluster.csv"
with open(filename2, 'w') as csvfile: 
    # creating a csv writer object 
    csvwriter = csv.writer(csvfile) 
        
    # writing the fields 
    
        
    # writing the data rows 
    csvwriter.writerows(X2)

# %%
arr2 = np.loadtxt(filename2,delimiter=',')

print(arr2)

plt.plot(arr2[:,0],arr2[:,1],'.')
plt.title("Subclustered Data")
# Out:
# [[  5.79634676  -6.03147129]
#  [  7.47941259   1.89070566]
#  [  7.63096793   2.85576007]
#  [  9.02021807   2.50500032]
#  [  8.52993888  -9.48125191]
#  [  8.70075397   3.00991207]
#  [  6.17157361  -5.68987684]
#  [  7.74143203   2.61421507]
#  [  8.74851161  -9.55482202]
#  [  6.28091405  -5.33819849]
#  [  9.544467    -9.01615923]
#  [  9.09815218 -10.37715707]
#  [  9.429763    -9.12029917]
#  [  7.94450983   2.62686626]
#  [  8.45204683   0.36586896]
#  [  9.96309117  -9.87889052]
#  [ -4.01653766  -4.0323734 ]
#  [  7.5584326    0.20416194]
#  [  7.98897521   2.90362538]
#  [  8.35690431   1.9764448 ]
#  [ -3.98967661  -2.36178   ]
#  [ -4.91633664  -3.55299473]
#  [  9.63151615 -10.16337161]
#  [  8.93353056  -9.8350652 ]
#  [  9.19222416  -9.32738004]
#  [  8.01878805   2.42393637]
#  [ -3.51226283  -2.84459992]
#  [  8.30863395 -10.04580135]
#  [  5.53784515  -5.5143648 ]
#  [  7.60242825  -6.13069043]
#  [  7.00372501  -0.612987  ]
#  [  9.56594506  -9.06103345]
# ...

# %%
plt.title("Skewed data", fontsize="small")
std = [0.5,0.5,0.5]
size = [150,50,50]
size = np.array(size).astype(int)
X3, Y3 = make_blobs(n_samples=size,n_features=2, centers=None,cluster_std=std,random_state=37)
plt.scatter(X3[:, 0], X3[:, 1], marker="o", c=Y2, s=25, edgecolor="k")

# %%
filename3 = "Skewed.csv"
with open(filename3, 'w') as csvfile: 
    # creating a csv writer object 
    csvwriter3 = csv.writer(csvfile) 
        
    # writing the fields 
    
        
    # writing the data rows 
    csvwriter3.writerows(X3)

# %%
arr3 = np.loadtxt(filename3,delimiter=',')

print(arr3)

plt.plot(arr3[:,0],arr3[:,1],'.')
plt.title("Skewed Data")
# Out:
# [[ 2.46586902  4.09383767]
#  [ 8.15433652  0.13969836]
#  [ 8.74894793 -0.56478329]
#  [ 3.13875133  2.94347145]
#  [ 9.1731843  -0.74241164]
#  [ 9.49164816 -1.1815611 ]
#  [ 9.04143124 -0.91026532]
#  [ 8.41696782 -1.44445486]
#  [ 2.86865541  3.37670172]
#  [ 2.03661374  2.91622788]
#  [-6.17455557  2.06254128]
#  [ 2.53948136  3.62427616]
#  [ 2.3017476   3.78221688]
#  [ 8.34651165 -0.76902397]
#  [-6.17455444  1.61498609]
#  [ 8.5765856   0.07463931]
#  [ 1.76854087  3.94382116]
#  [ 8.94571295 -1.53955767]
#  [-6.28291934  1.49280803]
#  [ 9.7615274  -1.77347368]
#  [ 9.30292421 -0.45045758]
#  [ 8.69200682 -0.08114863]
#  [ 2.43139488  3.10851095]
#  [ 9.27431972 -0.84659418]
#  [-5.79772091  2.32417092]
#  [ 8.84737026 -0.41833863]
#  [ 8.78281716 -1.05255887]
#  [ 9.05251456 -0.41991439]
#  [ 3.0469573   3.80689282]
#  [ 7.77448521 -1.0623128 ]
#  [ 9.09280799 -1.49287641]
#  [-5.79357457  2.08931448]
#  [-6.77825754  1.64806437]
#  [ 9.11201417 -1.74157023]
# ...

# %%
plt.title("Different Density", fontsize="small")
std = [0.82,1.4,1.1]
size = [90,80,80]
size = np.array(size).astype(int)
X3, Y3 = make_blobs(n_samples=size,n_features=2, centers=None,cluster_std=std,random_state=37)
plt.scatter(X3[:, 0], X3[:, 1], marker="o", c=Y2, s=25, edgecolor="k")

# %%
filename4 = "DifferentDensity.csv"
with open(filename4, 'w') as csvfile: 
    # creating a csv writer object 
    csvwriter3 = csv.writer(csvfile) 
        
    # writing the fields 
    
        
    # writing the data rows 
    csvwriter3.writerows(X3)

# %%
arr4 = np.loadtxt(filename4,delimiter=',')

print(arr4)

plt.plot(arr4[:,0],arr4[:,1],'.')
plt.title("Different Density Data")
# Out:
# [[ 2.54289080e+00  4.58506645e+00]
#  [ 7.68355537e+00  6.88648683e-01]
#  [-6.53885497e+00  2.06700657e+00]
#  [ 4.02323187e+00  2.05426076e+00]
#  [-5.35099314e+00  1.56964717e+00]
#  [ 9.87674646e+00 -1.47821683e+00]
#  [-5.71990170e+00  1.09965688e+00]
#  [ 8.11427070e+00 -1.90936260e+00]
#  [ 3.42902086e+00  3.00736735e+00]
#  [ 1.59852919e+00  1.99432491e+00]
#  [-6.22937663e+00  2.82690001e+00]
#  [ 2.70483796e+00  3.55203113e+00]
#  [ 2.18182367e+00  3.89950073e+00]
#  [ 7.99872260e+00 -8.01655942e-01]
#  [ 2.33468317e+00  3.63407516e+00]
#  [-7.02146951e+00  3.85738983e+00]
#  [ 1.00876887e+00  4.25503014e+00]
#  [-5.98791291e+00 -6.62361702e-01]
#  [-6.53279520e+00  1.23164691e+00]
#  [-3.70363245e+00 -1.31732653e+00]
#  [-4.98772141e+00  2.38711854e+00]
#  [ 8.56533466e+00  3.26459621e-01]
#  [ 2.46704768e+00  2.41734768e+00]
#  [-5.06781397e+00  1.27793608e+00]
#  [-5.17423959e+00  3.55946302e+00]
#  [ 8.82013071e+00 -2.26531992e-01]
#  [-6.44402113e+00  7.01234939e-01]
# ...
